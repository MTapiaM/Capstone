# %% [markdown]
# # Proyecto Final Certificado profesional de Ciencia de Datos de IBM -  Curso Capstone

# %%
import pandas as pd
import numpy as np

# %%
print("¡Hola, Proyecto Final del Curso!")
# Out:
# ¡Hola, Proyecto Final del Curso!
